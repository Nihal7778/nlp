# %% [markdown]
# <a href="https://colab.research.google.com/github/Nihal7778/nlp/blob/main/Text_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = "/content/drive/MyDrive/IMDB Dataset.csv"

# %%
df = pd.read_csv(data_path)

# %%
df.shape
# Out:
# (50000, 2)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.head(100)
# Out:
#                                                review sentiment
# 0   One of the other reviewers has mentioned that ...  positive
# 1   A wonderful little production. <br /><br />The...  positive
# 2   I thought this was a wonderful way to spend ti...  positive
# 3   Basically there's a family where a little boy ...  negative
# 4   Petter Mattei's "Love in the Time of Money" is...  positive
# ..                                                ...       ...
# 95  Daniel Day-Lewis is the most versatile actor a...  positive
# 96  My guess would be this was originally going to...  negative
# 97  Well, I like to watch bad horror B-Movies, cau...  negative
# 98  This IS the worst movie I have ever seen, as w...  negative
# 99  I have been a Mario fan for as long as I can r...  positive
#
# [100 rows x 2 columns]

# %%
df.shape
# Out:
# (50000, 2)

# %% [markdown]
# LOWER CASE PREPROCESSING

# %%
df['review'][3]
# Out:
# "Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them."

# %%
df['review'][3] = df['review'].str.lower()

# %%
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      0        one of the other reviewers has mentio...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
df['review'][3]
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production. <br /><br />the...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically there's a family where a little boy ...
# 4        petter mattei's "love in the time of money" is...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot, bad dialogue, bad acting, idiotic di...
# 49997    i am a catholic taught in parochial elementary...
# 49998    i'm going to have to disagree with the previou...
# 49999    no one expects the star trek movies to be high...
# Name: review, Length: 50000, dtype: object

# %% [markdown]
# HTML TAGS

# %%
import re
def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'', text)

# %%
text = "<html><body><p> Movie 1</p><p> Actor - Aamir Khan</p><p> Click here to <a href='http://google.com'>download</a></p></body></html>"

# %%
remove_html_tags(text)
# Out:
# ' Movie 1 Actor - Aamir Khan Click here to download'

# %%
df['review'] = df['review'].apply(lambda x: remove_html_tags(str(x)))

# %%
df['review'][6]
# Out:
# "I sure would like to see a resurrection of a up dated Seahunt series with the tech they have today it would bring back the kid excitement in me.I grew up on black and white TV and Seahunt with Gunsmoke were my hero's every week.You have my vote for a comeback of a new sea hunt.We need a change of pace in TV and this would work for a world of under water adventure.Oh by the way thank you for an outlet like this to view many viewpoints about TV and the many movies.So any ole way I believe I've got what I wanna say.Would be nice to read some more plus points about sea hunt.If my rhymes would be 10 lines would you let me submit,or leave me out to be in doubt and have me to quit,If this is so then I must go so lets do it."

# %% [markdown]
# remove_url

# %%
def remove_url(text):
    pattern = re.compile('https?://\S+|www\.\S+')
    return pattern.sub(r'', text)

# %%
text1 = 'Check out my Github https://github.com/Nihal7778'
text2 = 'Check out my linkedin https://www.linkedin.com/in/nihal778/'
text3 = 'Google search here www.google.com'
text4 = 'For data click https://www.kaggle.com/'

# %%
remove_url(text2)
# Out:
# 'Check out my linkedin '

# %% [markdown]
# punctuation landing

# %%
import string,time
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
exclude =string.punctuation #exlude- variable name
exclude
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punc(text):
  return text.translate(str.maketrans('','', exclude))

# %%
start =time.time()
remove_punc(text)
time2 = time.time()- start
print(time2*50000)
# Out:
# 6.699562072753906

# %%
df['review'][6]
# Out:
# "I sure would like to see a resurrection of a up dated Seahunt series with the tech they have today it would bring back the kid excitement in me.I grew up on black and white TV and Seahunt with Gunsmoke were my hero's every week.You have my vote for a comeback of a new sea hunt.We need a change of pace in TV and this would work for a world of under water adventure.Oh by the way thank you for an outlet like this to view many viewpoints about TV and the many movies.So any ole way I believe I've got what I wanna say.Would be nice to read some more plus points about sea hunt.If my rhymes would be 10 lines would you let me submit,or leave me out to be in doubt and have me to quit,If this is so then I must go so lets do it."

# %%
remove_punc(df['review'][6])
# Out:
# 'I sure would like to see a resurrection of a up dated Seahunt series with the tech they have today it would bring back the kid excitement in meI grew up on black and white TV and Seahunt with Gunsmoke were my heros every weekYou have my vote for a comeback of a new sea huntWe need a change of pace in TV and this would work for a world of under water adventureOh by the way thank you for an outlet like this to view many viewpoints about TV and the many moviesSo any ole way I believe Ive got what I wanna sayWould be nice to read some more plus points about sea huntIf my rhymes would be 10 lines would you let me submitor leave me out to be in doubt and have me to quitIf this is so then I must go so lets do it'

# %% [markdown]
# chat_conversation handle

# %%
chat_words = {
    "AFAIK": "As Far As I Know",
    "AFK": "Away From Keyboard",
    "ASAP": "As Soon As Possible",
    "ATK": "At The Keyboard",
    "ATM": "At The Moment",
}

# %%
def chat_conversion(text):
  new_text = []
  for w in text.split():
    if w.upper() in chat_words:
      new_text.append(chat_words[w.upper()])
  else:
        new_text.append(w)
  return " ".join(new_text)

# %%
chat_conversion('Do this work AFK')
# Out:
# 'Away From Keyboard AFK'

# %% [markdown]
# INCORRECT_TEXT_HANDLING

# %%
from textblob import TextBlob

# %%
incorrect_text = 'certainn conditons durling generaions are modifed in the same maner'

textBlb = TextBlob(incorrect_text)

textBlb.correct().string
# Out:
# 'certain conditions during generations are modified in the same manner'

# %% [markdown]
# stopwords

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
len(stopwords.words('english'))
# Out:
# 198

# %%
def remove_stopwords(text):
    new_text = []

    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    x = new_text[:]
    new_text.clear()
    return " ".join(x)

# %%
remove_stopwords('probably my all-time favorite movie, a story of selflessness, sacrifice and dedication to a noble cause, but it\'s not preachy or boring. it just never gets old, despite my having seen it some 15 or more times')
# Out:
# 'probably  all-time favorite movie,  story  selflessness, sacrifice  dedication   noble cause,    preachy  boring.   never gets old, despite   seen   15   times'

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. The filming tec...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  0        one of the other reviewers has mentio...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df['review'].apply(remove_stopwords)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3066797016.py in <cell line: 0>()
# ----> 1 df['review'].apply(remove_stopwords)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# ...

# %% [markdown]
# remove_emoji handle

# %%
import re
def remove_emoji(text):
    emoji_pattern =re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
remove_emoji('game is on 🔥🔥')
# Out:
# 'game is on '

# %%
# !pip install emoji
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 7.8 MB/s eta 0:00:00
# ...

# %%
import emoji
print(emoji.demojize('game is on 🔥'))
# Out:
# game is on :fire:

# %%
print(emoji.demojize('python is 🔥 '))
# Out:
# python is :fire:

# %% [markdown]
# Tokenization

# %% [markdown]
# 1. Using the split function

# %%
# word tokenization
sent1 = 'I am going to delhi'
sent1.split()
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %%
sent2 = 'I am going to hyderabad. Will be staying there for 5 days.Hoping to have a good time'
sent2.split('.')
# Out:
# ['I am going to hyderabad',
#  ' Will be staying there for 5 days',
#  'Hoping to have a good time']

# %% [markdown]
# 2. Regular Expression

# %%
import re
sent3 = 'I am going to delhi!'
tokens = re.findall("[\w']+", sent3) # pattern for word level "[\w']+"
tokens
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %%
text = """Lorem Ipsum is simply dummy text of the printing and typesetting industry?
Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,
when an unknown printer took a galley of type and scrambled it to make a type specimen book."""
sentences = re.compile('[.!?] ').split(text) #('[.!?] ') pattern for sentence level
sentences
# Out:
# ["Lorem Ipsum is simply dummy text of the printing and typesetting industry?\nLorem Ipsum has been the industry's standard dummy text ever since the 1500s,\nwhen an unknown printer took a galley of type and scrambled it to make a type specimen book."]

# %% [markdown]
# NLTK

# %%
from nltk.tokenize import word_tokenize,sent_tokenize
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
sent1 = 'I am going to visit delhi!'
word_tokenize(sent1)
# Out:
# ['I', 'am', 'going', 'to', 'visit', 'delhi', '!']

# %%
text = """Lorem Ipsum is simply dummy text of the printing and typesetting industry?
Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,
when an unknown printer took a galley of type and scrambled it to make a type specimen book."""

sent_tokenize(text)
# Out:
# ['Lorem Ipsum is simply dummy text of the printing and typesetting industry?',
#  "Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,\nwhen an unknown printer took a galley of type and scrambled it to make a type specimen book."]

# %%
sent5 = 'I have a Ph.D in A.I'
sent6 = "We're here to help! mail us at nks@gmail.com"
sent7 = 'A 5km ride cost $10.50'

word_tokenize(sent5)
# Out:
# ['I', 'have', 'a', 'Ph.D', 'in', 'A.I']

# %%
word_tokenize(sent6)
# Out:
# ['We',
#  "'re",
#  'here',
#  'to',
#  'help',
#  '!',
#  'mail',
#  'us',
#  'at',
#  'nks',
#  '@',
#  'gmail.com']

# %%
word_tokenize(sent7)
# Out:
# ['A', '5km', 'ride', 'cost', '$', '10.50']

# %% [markdown]
# 4. Spacy (good)

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc1 = nlp(sent5)
doc2 = nlp(sent6)
doc3 = nlp(sent7)
doc4 = nlp(sent1)

# %%
doc4 = nlp(sent1)
doc4
# Out:
# I am going to visit delhi!

# %%
for token in doc4:
    print(token)
# Out:
# I
# am
# going
# to
# visit
# delhi
# !

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. The filming tec...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  0        one of the other reviewers has mentio...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# Stemmer

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()
def stem_words(text):
    return " ".join([ps.stem(word) for word in text.split()])

# %%
sample = "walk walks walking walked"
stem_words(sample)
# Out:
# 'walk walk walk walk'

# %%
text = 'probably my alltime favorite movie a story of selflessness sacrifice and dedication to a noble cause but its not preachy or boring it just never gets old despite my having seen it some 15 or more times in the last 25 years paul lukas performance brings tears to my eyes and bette davis in one of her very few truly sympathetic roles is a delight the kids are as grandma says more like dressedup midgets than children but that only makes them more fun to watch and the mothers slow awakening to whats happening in the world and under her own roof is believable and startling if i had a dozen thumbs theyd all be up for this movie'
print(text)
# Out:
# probably my alltime favorite movie a story of selflessness sacrifice and dedication to a noble cause but its not preachy or boring it just never gets old despite my having seen it some 15 or more times in the last 25 years paul lukas performance brings tears to my eyes and bette davis in one of her very few truly sympathetic roles is a delight the kids are as grandma says more like dressedup midgets than children but that only makes them more fun to watch and the mothers slow awakening to whats happening in the world and under her own roof is believable and startling if i had a dozen thumbs theyd all be up for this movie

# %%
stem_words(text)
# Out:
# 'probabl my alltim favorit movi a stori of selfless sacrific and dedic to a nobl caus but it not preachi or bore it just never get old despit my have seen it some 15 or more time in the last 25 year paul luka perform bring tear to my eye and bett davi in one of her veri few truli sympathet role is a delight the kid are as grandma say more like dressedup midget than children but that onli make them more fun to watch and the mother slow awaken to what happen in the world and under her own roof is believ and startl if i had a dozen thumb theyd all be up for thi movi'

# %% [markdown]
# Lemmatization

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
wordnet_lemmatizer = WordNetLemmatizer()

sentence = "He was running and eating at same time. He has bad habit of swimming after playing long hours in the Sun."
punctuations="?:!.,;"
sentence_words = nltk.word_tokenize(sentence)
# Create a new list excluding punctuation
filtered_words = [word for word in sentence_words if word not in punctuations]

print("{0:20}{1:20}".format("Word","Lemma"))
for word in filtered_words:
    print ("{0:20}{1:20}".format(word,wordnet_lemmatizer.lemmatize(word,pos='v')))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipython-input-1799835423.py in <cell line: 0>()
#       8 sentence = "He was running and eating at same time. He has bad habit of swimming after playing long hours in the Sun."
#       9 punctuations="?:!.,;"
# ---> 10 sentence_words = nltk.word_tokenize(sentence)
#      11 # Create a new list excluding punctuation
#      12 filtered_words = [word for word in sentence_words if word not in punctuations]
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     140     :type preserve_line: bool
#     141     """
# ...

# %%
'/content/data/001ssb.txt (1).zip'
# Out:
# '/content/data/001ssb.txt (1).zip'

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-865732335.py in <cell line: 0>()
#       2
#       3 # Example: if it's tab-separated with "review" and "sentiment" columns
# ----> 4 df = pd.read_csv("001ssb.txt", sep="\t", names=["review", "sentiment"])
#       5
#       6 print(df.head())
#
# ...

# %% [markdown]
# NOTE: Stemming & lamatization are same to retrieve root words but lamatization is worked good. Lamatization is slow & stemming is fast

# %%
# !pip install gensim

# %%
import numpy as np
import pandas as pd
import gensim
import os

# %%
# !pip install --upgrade gensim --user

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
import os
from nltk.tokenize import sent_tokenize
from gensim.utils import simple_preprocess

# Make sure you've done this once somewhere in your setup:
# import nltk; nltk.download('punkt')

story = []
data_dir = 'data'

for name in os.listdir(data_dir):
    path = os.path.join(data_dir, name)
    if not os.path.isfile(path):      # skip directories like .ipynb_checkpoints
        continue

    with open(path, encoding='utf-8', errors='ignore') as f:
        corpus = f.read()

    for sent in sent_tokenize(corpus):
        story.append(simple_preprocess(sent))

# %%
story
# Out:
# [['pk',
#   'roma',
#   'ssb',
#   'txt',
#   'ctj',
#   '眽auz궫svn',
#   'hfg',
#   'y_',
#   'ɸá',
#   'xjo',
#   'mw_s',
#   'yj',
#   'ﺩňn',
#   'giz',
#   'mӹf',
#   'yߤynms',
#   'lc',
#   'elxmizn',
#   'vwyvl',
#   'lcs',
#   'on',
#   'lwv',
#   'jjs',
#   'vm',
#   'xyoc',
#   'ӱi',
#   'vn',
#   'skl',
#   'mz',
#   'õnii',
#   'hk',
#   'ss',
#   'xu',
#   'joh',
#   'nlѵij',
#   'ĩii',
#   'fjd',
#   'tq',
#   'mfxy',
#   'xm',
#   'ori',
#   'zm',
#   'ۊv',
#   'no',
#   'ɏmޘ',
#   'ds'],
#  ['yۅռmc',
#   'xmkdjcwxep',
#   'զz',
#   'ڶlw',
#   'ޚy',
#   'aڛ',
#   'bv힛mo',
#   'ynvy',
#   'vl',
#   'dd',
#   'hz',
#   'ax',
#   'oj',
#   'fa',
#   'so',
#   'ح갾m',
#   'ʍzmxln',
#   'kmo',
#   'eki',
#   'okke',
#   'jyy',
#   'ya',
#   'kt'],
#  ['dbjjfhyo',
#   'oszyz',
#   'vpӧ',
#   'vc',
#   'lb',
#   'anǉkx',
#   'xlۃ',
#   'vi',
#   'ͷiwov',
#   'xenze',
#   'ft',
#   'duv',
#   'skh',
#   'nmc',
#   'nu',
#   'it',
#   'bj',
#   'bheg',
#   'uj'],
#  ['zs',
# ...

# %%
len(story)
# Out:
# 1119

# %%
story[0]
# Out:
# ['pk',
#  'roma',
#  'ssb',
#  'txt',
#  'ctj',
#  '眽auz궫svn',
#  'hfg',
#  'y_',
#  'ɸá',
#  'xjo',
#  'mw_s',
#  'yj',
#  'ﺩňn',
#  'giz',
#  'mӹf',
#  'yߤynms',
#  'lc',
#  'elxmizn',
#  'vwyvl',
#  'lcs',
#  'on',
#  'lwv',
#  'jjs',
#  'vm',
#  'xyoc',
#  'ӱi',
#  'vn',
#  'skl',
#  'mz',
#  'õnii',
#  'hk',
#  'ss',
#  'xu',
#  'joh',
#  'nlѵij',
#  'ĩii',
#  'fjd',
#  'tq',
#  'mfxy',
#  'xm',
#  'ori',
#  'zm',
#  'ۊv',
#  'no',
#  'ɏmޘ',
#  'ds']

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2
)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (90735, 178235)

# %%
model.wv.most_similar('xu')
# Out:
# [('lf', 0.9993053078651428),
#  ('wm', 0.9992867112159729),
#  ('qn', 0.9992421865463257),
#  ('mg', 0.9992285370826721),
#  ('qm', 0.9992155432701111),
#  ('hd', 0.9992019534111023),
#  ('nu', 0.9991986751556396),
#  ('nn', 0.9991871118545532),
#  ('ct', 0.999186635017395),
#  ('fn', 0.9991819262504578)]

# %%
model.wv.similarity('vm','ss')
# Out:
# 0.9988392

# %%
story
# Out:
# [['pk',
#   'roma',
#   'ssb',
#   'txt',
#   'ctj',
#   '眽auz궫svn',
#   'hfg',
#   'y_',
#   'ɸá',
#   'xjo',
#   'mw_s',
#   'yj',
#   'ﺩňn',
#   'giz',
#   'mӹf',
#   'yߤynms',
#   'lc',
#   'elxmizn',
#   'vwyvl',
#   'lcs',
#   'on',
#   'lwv',
#   'jjs',
#   'vm',
#   'xyoc',
#   'ӱi',
#   'vn',
#   'skl',
#   'mz',
#   'õnii',
#   'hk',
#   'ss',
#   'xu',
#   'joh',
#   'nlѵij',
#   'ĩii',
#   'fjd',
#   'tq',
#   'mfxy',
#   'xm',
#   'ori',
#   'zm',
#   'ۊv',
#   'no',
#   'ɏmޘ',
#   'ds'],
#  ['yۅռmc',
#   'xmkdjcwxep',
#   'զz',
#   'ڶlw',
#   'ޚy',
#   'aڛ',
#   'bv힛mo',
#   'ynvy',
#   'vl',
#   'dd',
#   'hz',
#   'ax',
#   'oj',
#   'fa',
#   'so',
#   'ح갾m',
#   'ʍzmxln',
#   'kmo',
#   'eki',
#   'okke',
#   'jyy',
#   'ya',
#   'kt'],
#  ['dbjjfhyo',
#   'oszyz',
#   'vpӧ',
#   'vc',
#   'lb',
#   'anǉkx',
#   'xlۃ',
#   'vi',
#   'ͷiwov',
#   'xenze',
#   'ft',
#   'duv',
#   'skh',
#   'nmc',
#   'nu',
#   'it',
#   'bj',
#   'bheg',
#   'uj'],
#  ['zs',
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
X
# Out:
# array([[-0.06081897,  0.00292053, -0.00080297],
#        [-0.06124997, -0.00054609,  0.00045281],
#        [-0.06172937,  0.00392369, -0.00358296],
#        ...,
#        [ 0.04477036, -0.02876696, -0.05686755],
#        [ 0.001957  ,  0.00918434, -0.01236296],
#        [ 0.0220136 ,  0.02164518, -0.00857354]], dtype=float32)

# %%
X.shape
# Out:
# (1635, 3)

# %%
import pandas as pd
import plotly.express as px

rows = slice(200, 300)  # 200..299
plot_df = pd.DataFrame(X[rows, :3], columns=['x0','x1','x2'])
plot_df['sentiment'] = df['sentiment'].iloc[rows].to_numpy()

fig = px.scatter_3d(plot_df, x='x0', y='x1', z='x2', color='sentiment')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-951357293.py in <cell line: 0>()
#       4 rows = slice(200, 300)  # 200..299
#       5 plot_df = pd.DataFrame(X[rows, :3], columns=['x0','x1','x2'])
# ----> 6 plot_df['sentiment'] = df['sentiment'].iloc[rows].to_numpy()
#       7
#       8 fig = px.scatter_3d(plot_df, x='x0', y='x1', z='x2', color='sentiment')
#
# NameError: name 'df' is not defined

# %%
# !git config --global user.email "nihal77778@gmail.com"
# !git config --global user.name "nihal77778"

# %%
# !git clone https://github.com/nihal77778/nlp.git
# Out:
# Cloning into 'nlp'...
# fatal: could not read Username for 'https://github.com': No such device or address
